# %%
############## Matplot ################

# %%
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#Matplotlib is open source and we can use it freely.
#Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# The plot() function is used to draw points (markers) in a diagram.
#
#
# By default, the plot() function draws a line from point to point.
#
#
# The function takes parameters for specifying points in the diagram.
#
#
# Parameter 1 is an array containing the points on the x-axis.
#
#
# Parameter 2 is an array containing the points on the y-axis.

# %%
#To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([1,10])
ypoints =np.array([5,10])

plt.plot(xpoints,ypoints,"o")
plt.show()

# %%
import matplotlib.pyplot as pyplot
import numpy as np

xpoints = np.array([1,2,5,8])
ypoints = np.array([3,8,1,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1,3,2,9,4])

plt.plot(ypoints)#here xpoints are default as 0,1,2,3,4,5
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1,3,2,9,4])

plt.plot(ypoints,marker ="*")#here xpoints are default as 0,1,2,3,4,5
plt.show()

# %%
# Marker	Description
# 'o'	Circle	
# '*'	Star	
# '.'	Point	
# ','	Pixel	
# 'x'	X	
# 'X'	X (filled)	
# '+'	Plus	
# 'P'	Plus (filled)	
# 's'	Square	
# 'D'	Diamond	
# 'd'	Diamond (thin)	
# 'p'	Pentagon	
# 'H'	Hexagon	
# 'h'	Hexagon	
# 'v'	Triangle Down	
# '^'	Triangle Up	
# '<'	Triangle Left	
# '>'	Triangle Right	
# '1'	Tri Down	
# '2'	Tri Up	
# '3'	Tri Left	
# '4'	Tri Right	
# '|'	Vline	
# '_'	Hline

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:')# lines dotted or dashed or straight
plt.show()

# %% [markdown]
# '-'	Solid line
#
# ':'	Dotted line
#
# '--'	Dashed line
#
# '-.'	Dashed/dotted line

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'p:c') #colour
plt.show()

# %% [markdown]
# Color Syntax	Description
#
# 'r'	Red
#
# 'g'	Green
#
# 'b'	Blue
#
# 'c'	Cyan
#
# 'm'	Magenta
#
# 'y'	Yellow
#
# 'k'	Black
#
# 'w'	White

# %%
#marker size
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'p:r',ms =15) #marker size
plt.show()

# %%
#marker edge colour and marker face colour
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

#marker edge colour and marker face colour
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
# linestyle can be written as ls.

# dotted can be written as :.

# dashed can be written as --.

plt.plot(ypoints, ls = ':')#ls represents linestyle

# %%
#line colour
plt.plot(ypoints, color = 'r')
#linewidth
plt.plot(ypoints,lw=10)#linewidth is reppresnted as lw

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)#plotting two lines of both x and y in samefucntion
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

#font1 = {"family":"serif","color":"blue","size":20}
#font2 = {"family":"serif","color":green","size":15}


plt.title("Sports Watch Data", fontdict = font1,loc="left")
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
plt.grid()#grid implements a grid on
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.grid(axis="x")

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1) # in this the plot is dividd into two through 1 row 
#2 cloumns and the number of the plot like (1,2,1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)# in this the plot is divided into two, through 1 row 
#2 cloumns and the number of the plot like (1,2,2)
plt.plot(x,y)

plt.show()

# %%
plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
# Out:
# <Axes: >

# %%
#You can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot.
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#You can add a title to the entire figure with the 
#suptitle() function:
#this fucntion is used at the last like

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y,color="red")
plt.show()

# %%
#plt.bar(x, y, width = 0.1) it gives width of the bar line

#The barh() takes the keyword argument height to set the height of the bars:

# %% [markdown]
# A histogram is a graph showing frequency distributions.
#
#
# It is a graph showing the number of observations within each given interval.
#
#
# Example: Say you ask for the height of 250 people, you might end up with a histogram like this:

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [159.6678737  169.53621168 164.92391709 171.98769322 189.26733954
#  157.03095153 178.49865767 180.76221604 173.13134524 184.83908653
#  169.67569722 162.48130894 185.20694573 171.58294492 180.60064745
#  165.71378185 164.92101531 168.4910478  183.23434491 156.06346557
#  172.28564019 172.46097643 179.2776683  168.00958147 177.40697959
#  162.42158972 165.03991813 165.8963377  171.24916738 168.64531898
#  157.62403495 187.76913965 187.6524462  176.815126   160.68474196
#  158.18964922 161.5110979  184.94737581 180.58237128 176.92702475
#  176.47282567 158.32728099 177.91885458 173.06014202 166.10696738
#  172.29256659 167.09192633 162.15060051 168.96680845 190.05107141
#  163.94995701 150.5631635  158.1882883  160.91537827 162.25765856
#  167.02987626 170.22304652 184.12750827 170.67218944 156.94459353
#  174.61708081 179.84273199 173.4900036  174.57891389 172.891261
#  172.21830697 168.17355605 152.18803032 175.53845109 173.9843016
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle =90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title="four fruits:")
plt.show()

# %%
########################scatter()is left########################
